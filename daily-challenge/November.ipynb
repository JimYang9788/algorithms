# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    res = []
    def accTraversal (self, root):
        if not root:
            return 
        else:
            self.accTraversal(root.left)
            self.res.append (root.val)
            self.accTraversal(root.right)
        return self.res      
    
    def inorderTraversal(self, root: TreeNode) -> List[int]:
        self.res = []
        return self.accTraversal(root)
# Out:
#   File "<ipython-input-2-a064c31ca5b5>", line 1
#     Definition for a binary tree node.
#                  ^
# SyntaxError: invalid syntax

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

    
    def zigzagLevelOrder(self, root: TreeNode) -> List[List[int]]:
        if not root: return []
        
        res = []
        Q = []
        Q.append (root)
        left_to_right = 1 
        while Q:
            next_level = []
            for node in Q:
                if node.left:
                    next_level.append (node.left)
                if node.right:
                    next_level.append (node.right)
            
            if left_to_right:
                res.append ([node.val for node in Q])
            else:
                Q.reverse()
                res.append ([node.val for node in Q])
            left_to_right = 1 - left_to_right
            
            Q = next_level
        return res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d1fbbabce77> in <module>
#       5 #         self.left = left
#       6 #         self.right = right
# ----> 7 class Solution:
#       8
#       9
#
# <ipython-input-1-6d1fbbabce77> in Solution()
#       8
#       9
# ---> 10     def zigzagLevelOrder(self, root: TreeNode) -> List[List[int]]:
#      11         if not root: return []
#      12
#
# NameError: name 'TreeNode' is not defined

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:

        
    def buildTree(self, preorder: List[int], inorder: List[int]) -> TreeNode:
        
        if not inorder: return None
        
        mid = preorder[0]
        mid_pos = inorder.index (mid)
        
        treenode = TreeNode (mid,None,None)
        treenode.left = self.buildTree(preorder[1:1+mid_pos],inorder[0:mid_pos])
        treenode.right = self.buildTree(preorder[1+mid_pos:],inorder[mid_pos+1:])
        
        return treenode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9f2251ed34df> in <module>
#       5 #         self.left = left
#       6 #         self.right = right
# ----> 7 class Solution:
#       8
#       9
#
# <ipython-input-2-9f2251ed34df> in Solution()
#       8
#       9
# ---> 10     def buildTree(self, preorder: List[int], inorder: List[int]) -> TreeNode:
#      11
#      12         if not inorder: return None
#
# NameError: name 'List' is not defined

# %%
"""
# Definition for a Node.
class Node:
    def __init__(self, val: int = 0, left: 'Node' = None, right: 'Node' = None, next: 'Node' = None):
        self.val = val
        self.left = left
        self.right = right
        self.next = next
"""

class Solution:
    def connect(self, root: 'Node') -> 'Node':
        if not root: return None 
        
        
        Q = []
        Q.append (root)
        while Q:
            next_level = []
            for node in Q:
                if node.left:
                    next_level.append (node.left) 
                if node.right:
                    next_level.append (node.right)
                    
            for i,node in enumerate(Q):
                if i != len(Q) -1:
                    node.next = Q[i+1]
                else:
                    node.next = None 
            Q = next_level 
        return root

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Info:
    def __init__(self, size, node):
        self.size = size
        self.node = node 
        

class Solution:
    size_tree = Info(0,None)
    
    def update_size_tree (self, root):
        if not root:
            return Info (0, None)
        
        linfo = self.update_size_tree(root.left) 
        rinfo = self.update_size_tree(root.right)
         
        newinfo = Info(0,None)
        newinfo.node = TreeNode (0,None,None)
        newinfo.node.left = linfo
        newinfo.node.right = rinfo 
        newinfo.size = linfo.size + rinfo.size + 1 
        
        return newinfo
    
    def binary_search (self, root, size_tree,k):
        # size_tree is never empty 
        if not root:
            print ("Fucked up")
        l = size_tree.node.left.size if size_tree.node.left else 0 
        r = size_tree.node.right.size if size_tree.node.right else 0 
        m = size_tree.size - r 
        
        if k == m:
            return root.val
        elif k < m:
            return self.binary_search (root.left, size_tree.node.left ,k)
        else:
            return self.binary_search (root.right, size_tree.node.right, k - m)
        
    
    def kthSmallest(self, root: TreeNode, k: int) -> int:
        size_tree = Info(0,None)
        self.size_tree = self.update_size_tree (root)
        return self.binary_search(root,self.size_tree,k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cc2a17facdf1> in <module>
#      12
#      13
# ---> 14 class Solution:
#      15     size_tree = Info(0,None)
#      16
#
# <ipython-input-4-cc2a17facdf1> in Solution()
#      46
#      47
# ---> 48     def kthSmallest(self, root: TreeNode, k: int) -> int:
#      49         size_tree = Info(0,None)
#      50         self.size_tree = self.update_size_tree (root)
#
# NameError: name 'TreeNode' is not defined

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    
    def inorderSuccessor(self, root: 'TreeNode', p: 'TreeNode') -> 'TreeNode':
        
        
        bloodline = []
        curnode = root 
        target = None 
        while (curnode):
            bloodline.append (curnode)
            if curnode.val == p.val:
                target = curnode 
                break
            elif curnode.val < p.val:
                curnode = curnode.right 
            else:
                curnode = curnode.left 
        
        if curnode.right: 
            curnode = curnode.right
            while(curnode.left):
                curnode = curnode.left 
            return curnode 
        elif bloodline == []:
            return None
        else:
            bloodline.reverse()
            for member in bloodline:
                if member.val > target.val:
                    return member
            return None
