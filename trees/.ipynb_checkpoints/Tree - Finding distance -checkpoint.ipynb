# %%
# This is an input class. Do not edit.
class BinaryTree:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

def findNodesDistanceK(tree, target, k):
	# returns the values of all the nodes that are 
	# Exactly distance k from the node with target value

	# Return a list of numbers 
	# order does not matter 
	
	def updateChildren(tree, k):
	# update all the children that are 
	# k steps away from the current node 
		if not tree:
			return 
		if k == 0:
			results.append(tree.value)
			return 
		else:
			updateChildren(tree.left, k - 1)
			updateChildren(tree.right, k - 1)


	def findDistance (tree, target, k):
		# Find the distance between the current node to k
		# Then find k distances nodes

		if not tree: return 0

		if tree.value == target:
			updateChildren(tree, k)
			return 1 

		leftDistance = findDistance (tree.left, target, k)
		if leftDistance:
			if k == leftDistance:
				results.append(tree.value)		
			updateChildren(tree.right, k - leftDistance - 1)
			return leftDistance + 1 

		rightDistance = findDistance (tree.right, target, k,)
		if rightDistance:
			if k == rightDistance :
				results.append(tree.value)
			updateChildren(tree.left, k - rightDistance - 1)

			return rightDistance + 1  
	
	results = []
	
	findDistance(tree,target,k)

	return results
