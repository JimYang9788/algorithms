# %%
class Solution:
    def openLock(self, deadends, target: str) -> int:
        
        # Use BFS 
        
        
        def addOne (c):
            if c == '9':
                return '0'
            else:
                return str(int (c) + 1)
        
        def minusOne (c):
            if c == '0':
                return '9'
            else:
                return str(int (c) - 1)
            
        def getNeighbour (lock):
            # Ret a list of reachable comb
            res = []
            for i in range (len(lock)):
                res.append (lock[:i] + addOne(lock[i]) + lock[i+1:])                
                res.append (lock[:i] + minusOne(lock[i]) + lock[i+1:])               
            return res
        
    
        
        queue = ["0000"] 
            
        visited = set()
        step = 0 
        
        while (queue):
            length = len (queue)
            for i in range (length):
                curnode = queue.pop(0)
                if curnode in deadends:
                    continue                 
                if curnode == target:
                    return step
                for neighbour in getNeighbour(curnode):
                    if neighbour not in visited:
                        queue.append (neighbour)
                        visited.add (neighbour)
                
            step += 1 
            
        return -1

# %%
class Solution:
    # 双向BFS， 加visited的点非常的微妙，这次是在visited queue1
    # stack的时候进行的visited
    def openLock(self, deadends: List[str], target: str) -> int:
        
        # Use BFS 
        
        
        def addOne (c):
            if c == '9':
                return '0'
            else:
                return str(int (c) + 1)
        
        def minusOne (c):
            if c == '0':
                return '9'
            else:
                return str(int (c) - 1)
            
        def getNeighbour (lock):
            # Ret a list of reachable comb
            res = []
            for i in range (len(lock)):
                res.append (lock[:i] + addOne(lock[i]) + lock[i+1:])                
                res.append (lock[:i] + minusOne(lock[i]) + lock[i+1:])               
            return res
        
    
        
        queue = set ()
        queue2 = set ()
        visited = set()

        queue.add ("0000")        
        queue2.add (target)
        step = 0 
        
        while (queue and queue2):
            temp = set()
            for curnode in queue:
                if curnode in deadends:
                    continue                 
                if curnode in queue2:
                    return step
                
                visited.add (curnode) # 这个房visited的时机很微妙...
                
                for neighbour in getNeighbour(curnode):
                    if neighbour not in visited:
                        temp.add (neighbour)
            step += 1 

            queue = queue2.copy()
            queue2 = temp.copy()
            
            
        return -1
