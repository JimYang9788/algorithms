# %%
# This is an input class. Do not edit.
class Node:
    def __init__(self, value):
        self.value = value
        self.prev = None
        self.next = None


# Feel free to add new properties and methods to the class.
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def setHead(self, node):

		curnode = self.head
		if self.head == curnode and self.tail == curnode:
			return 
		
		# Check if node is in the Linkedlist, 
		# If so, remove 
        while curnode:
			if curnode.val == node.val:
				if curnode.prev:
					curnode.prev.next = curnode.next 
				if curnode.next:
					curnode.next.prev = curnode.prev 

		# Set the head 
		if node.head:
			tmp = self.head 
			node.head = node
			node.head.next = tmp 
			tmp.prev = node.head 
			
		else:
			self.head = node 
			self.tail = node 
		

    def setTail(self, node):
        # Write your code here.
		curnode = self.head
		if self.head == curnode and self.tail == curnode:
			return 
		
		# Check if node is in the Linkedlist, 
		# If so, remove 
        while curnode:
			if curnode.val == node.val:
				if curnode.prev:
					curnode.prev.next = curnode.next 
				if curnode.next:
					curnode.next.prev = curnode.prev 

		# Set the head 
		if node.tail:
			tmp = self.tail 
			node.tail = node
			node.tail.prev = tmp 
			tmp.next = node.tail 
			
		else:
			self.head = node 
			self.tail = node 
		
    def insertBefore(self, node, nodeToInsert):
        # Write your code here.
        pass

    def insertAfter(self, node, nodeToInsert):
        # Write your code here.
        pass

    def insertAtPosition(self, position, nodeToInsert):
        # Write your code here.
        pass

    def removeNodesWithValue(self, value):
        # Write your code here.
        pass

    def remove(self, node):
        # Write your code here.
        pass

    def containsNodeWithValue(self, value):
        # Write your code here.
        pass
# Out:
#   File "<tokenize>", line 23
#     while curnode:
#     ^
# IndentationError: unindent does not match any outer indentation level
